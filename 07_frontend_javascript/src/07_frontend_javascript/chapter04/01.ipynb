// %% [markdown]
// ## 4장 1강 : JavaScript 개발 환경 구성

// %% [markdown]
// JavaScript
// - Interpreter Language
// - Javascript Interpretation Engine
// - Web Browser(Chrome) - "V8"
// - Node.js - "V8"
//
//
//
// Node.js
//   - node   → JavaScript 실행 runtime
//   - nvm (Node Version Manager) → /Users/myungjilee/Desktop/Kant/ax_study/07_frontend_javascript/src/07_frontend_javascript
//   - npm(Node Package Manager)    → 패키지 설치/관리 (외부 패키지 설치시 사용 명령어)
//   - npx(Node Package Executor)    → 패키지를 바로 실행

// %% [markdown]
// ### 1. 개발 환경 구축: 로컬 프로젝트 생성 및 Jupyter 커널 등록

// %% [markdown]
// #### 1.1 웹 브라우저도 자바스크립트 번역기입니다

// %% [markdown]
// #### 1.2 Node.js 설치 과정
// - Node.js (node)
// - NPM
// - NPX
// - NVM (Node Version Manager) 설치
//
// - 알아두면 유용한 주요 npm 명령어 및 옵션
//     - install / i
//     - uninstall / un
//     - --yes / -y
//     - --save-dev / -D
//     - --gloabl / -g

// %% [markdown]
// #### 1.3 로컬 프로젝트 생성 및 자바스크립트 커널 설치
// - tslab

// %%
var a = 100;
console.log(a)
// Out:
// 100

// %%
function addNumbers(x, y, z) {
    return x + y + z;
}

console.log(addNumbers(1, 2, 3 ));
// Out:
// 6
