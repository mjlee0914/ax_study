# %% [markdown]
# # Supabase 연동하기

# %% [markdown]
# - `.env` file은 github에 절대 올라가면 안됨 -> .gitignore에 추가

# %% [markdown]
# - .env SUPABASE 주소, 키 -> 환경변수로 설정 완료

# %% [markdown]
# [UUID Universally Unique Identifier]
# - ![image.png](attachment:image.png)
# - 만들때마다 다른 형식의 식별자 코드가 생성됨
# - 8-4-4-4-12자
# - 용도: 사용자 식별 보안 강화
