# %% [markdown]
# # Supabase 연동하기

# %%
import os
from supabase import create_client

url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_PUBLISHABLE_KEY")

print(url,"|",key)

# SUPABASE Client 객체 생성
supabase_client = create_client(url, key)
print(supabase_client)
# Out:
# https://flnbcdmevintcqgcsvmi.supabase.co | sb_publishable_i-hTNyR1fZDugNzSwpTG-w_BTz-q-fh
# <supabase._sync.client.Client object at 0x110123c50>

# %%
from dotenv import load_dotenv

# .env 파일 환경변수 불러오기 (민감한 정보는 이렇게 불러오기)
load_dotenv()

num1 = os.getenv("CONFIG_NUM1")
str1 = os.getenv("CONFIG_STR")

print(num1, str1)
# Out:
# 100 ABC
