# %% [markdown]
# # 7장 2강 : 디버깅 기초

# %% [markdown]
# ## 1. 에러 트레이스백(Traceback)과  해석 방법

# %% [markdown]
# ### 1.1 에러 트레이스백(Traceback)

# %%
def 훈련_함수():
    print(존재하지않는변수) # 정의되지 않은 이름 공간 호출로 NameError 유발

# 호출 시 인터프리터가 아래에서 위로 호출 경로를 추적하는 Traceback을 출력합니다.
훈련_함수()

# %% [markdown]
# ### 1.2 임시 print() 함수를 통한 디버깅과 한계

# %%
total = 0
for i in range(100):
    total += i
    # 반복 횟수가 많아질수록 대량의 텍스트가 출력창을 오염시켜 흐름 식별을 방해함
    print(f"임시 로깅 수치 - i: {i}, 현재 total: {total}")

# %% [markdown]
# ## 2. VS Code 디버거 설치 및 흐름 제어

# %% [markdown]
# ### 2.1 VS Code 디버거 설치

# %%
sample_list = [10, 20, 30]
print("디버그 셀 실행 준비 완료")

# %% [markdown]
# ### 2.2 중단점(Breakpoint)과 Variables 패널의 활용

# %%
base_score = 100
bonus_score = 50 # 이 라인 왼쪽 여백을 클릭하여 빨간색 중단점(●)을 설정합니다.

# 인터프리터가 정지하면 좌측 Variables 패널에서 base_score와 bonus_score 수치를 확인합니다.
final_score = base_score + bonus_score
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 base_score = 100
# ----> 2 bonus_score = 50 # 이 라인 왼쪽 여백을 클릭하여 빨간색 중단점(●)을 설정합니다.
#       4 # 인터프리터가 정지하면 좌측 Variables 패널에서 base_score와 bonus_score 수치를 확인합니다.
#       5 final_score = base_score + bonus_score
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
# ---> 69 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring/_pydevd_sys_monitoring_cython.pyx:1505, in _pydevd_sys_monitoring_cython._line_event()
# -> 1505 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring/_pydevd_sys_monitoring_cython.pyx:1547, in _pydevd_sys_monitoring_cython._internal_line_event()
# -> 1547 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring/_pydevd_sys_monitoring_cython.pyx:1348, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
# -> 1348 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring/_pydevd_sys_monitoring_cython.pyx:1990, in _pydevd_sys_monitoring_cython._do_wait_suspend()
# -> 1990 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\Documents\ax_study\02_PYTHON\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2234, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2231             from_this_thread.append(frame_custom_thread_id)
#    2233     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2234         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2236 frames_list = None
#    2238 if keep_suspended:
#    2239     # This means that we should pause again after a set next statement.
#
# File ~\Documents\ax_study\02_PYTHON\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2303, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2300                 queue.put(internal_cmd)
#    2301                 wait_timeout = TIMEOUT_FAST
# -> 2303         notify_event.wait(wait_timeout)
#    2304         notify_event.clear()
#    2306 finally:
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\threading.py:660, in Event.wait(self, timeout)
#     658 signaled = self._flag
#     659 if not signaled:
# --> 660     signaled = self._cond.wait(timeout)
#     661 return signaled
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2.3 디버거 주요 흐름 제어 명령어의 특징

# %%
def 가공_프로세스(n):
    return n * 2 # 'Step Into' 명령 수행 시에만 이 내부 라인으로 제어권이 진입합니다.

number = 10
# 'Step Over' 명령을 수행하면 함수 내부로 들어가지 않고 최종 연산 결과값만 도출하여 다음 줄로 넘어갑니다.
result = 가공_프로세스(number) 
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 number = 10
#       5 # 'Step Over' 명령을 수행하면 함수 내부로 들어가지 않고 최종 연산 결과값만 도출하여 다음 줄로 넘어갑니다.
# ----> 6 result = 가공_프로세스(number)
#       7 print(result)
#
# Cell In[7], line 2, in 가공_프로세스(n)
#       1 def 가공_프로세스(n):
# ----> 2     return n * 2
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_4904d5__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_11instruction_6retval.wrap()
# ---> 69 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring/_pydevd_sys_monitoring_cython.pyx:1152, in _pydevd_sys_monitoring_cython._return_event()
# -> 1152 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring/_pydevd_sys_monitoring_cython.pyx:1287, in _pydevd_sys_monitoring_cython._stop_on_return()
# -> 1287 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring/_pydevd_sys_monitoring_cython.pyx:1990, in _pydevd_sys_monitoring_cython._do_wait_suspend()
# -> 1990 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\Documents\ax_study\02_PYTHON\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2234, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2231             from_this_thread.append(frame_custom_thread_id)
#    2233     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2234         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2236 frames_list = None
#    2238 if keep_suspended:
#    2239     # This means that we should pause again after a set next statement.
#
# File ~\Documents\ax_study\02_PYTHON\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2303, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2300                 queue.put(internal_cmd)
#    2301                 wait_timeout = TIMEOUT_FAST
# -> 2303         notify_event.wait(wait_timeout)
#    2304         notify_event.clear()
#    2306 finally:
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\threading.py:660, in Event.wait(self, timeout)
#     658 signaled = self._flag
#     659 if not signaled:
# --> 660     signaled = self._cond.wait(timeout)
#     661 return signaled
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3. 트레이스백 분석 및 디버깅

# %% [markdown]
# ### 3.1 에러 트레이스백 경로 추적 및 결함 지점 이동

# %%
def calculate_average(scores):
    total = sum(scores)
    count = len(scores)
    average = total / count  # 결함 발생 예측 지점
    return average

def process_report():
    student_scores = []  # 비어있는 리스트 데이터 주입
    result = calculate_average(student_scores)
    print(f"평균 점수: {result}")

# 함수 호출을 통해 실행 흐름을 시작합니다.
process_report()

# %% [markdown]
# ### 3.2 Debug Cell 활성화를 통한 단계별 변수 상태 검증

# %%
# 실행 전, 4번째 라인인 'total += i' 왼쪽 공간을 클릭하여 빨간색 중단점(Breakpoint)을 설정합니다.
def accumulate_data():
    total = 0
    for i in range(1, 4):
        total += i  # [● 중단점 설정 위치 - 코드 왼쪽 여백 클릭]
    return total

# 셀 실행 버튼 옆의 드롭다운을 눌러 'Debug Cell'을 선택하여 디버거를 실행합니다.
final_result = accumulate_data()
print(f"최종 합계: {final_result}")
# Out:
# 최종 합계: 6
